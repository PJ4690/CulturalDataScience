# %% [markdown]
# # Build your own concordance
#
# It took 500 Dominican munks to write the first concordance of the Latin bible, and it took Rabbi Mordecai Nathan 10 years to write the first concordance of the Hebrew bible. With Python, it only takes a matter of seconds to find words in a text, along with the surrounding words.
#
# Run each cell in this notebook one at a time, in order. If something in one cell doesn't work right, it might be because you have overwritten a variable, so try going back and running all the previous cells again.
#
# First run the code and check that everything works. Then, try modifying the code. Start with the first challenges, and then continue in order. Feel free to work together, and see how far you can get. The important thing is to learn, not to solve all the challenges!

# %%
# install the natural language toolkit package (nltk), which has a copy of several texts, 
#including the King James Bible

# %pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.4.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.2)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.7 MB/s eta 0:00:00
# Downloading regex-2024.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (782 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.7/782.7 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.9.1 regex-2024.9.11
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the nltk package so that it is accessible to Python, and download a collection of texts from Project Gutenberg
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /home/ucloud/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
# Create a variable called "bible" which contains the text of the King James bible.
bible = nltk.corpus.gutenberg.raw('bible-kjv.txt')

# make all characters lowercase
bible = bible.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
bible = bible.replace('\n', ' ')

# split up the text into a long list of individual words
bible = bible.split(' ')

# %%
# make a variable called "concordance", and fill it with every occurrence of the phrase "this world", and a few words preceeding and following "this world"
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        if bible[i-1] == "this":
            concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['for the children of this world are in their generation',
#  'them, the children of this world marry, and are given',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'for the prince of this world cometh, and hath nothing',
#  'because the prince of this world is judged.  16:12',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'for the fashion of this world passeth away.  7:32',
#  'whom the god of this world hath blinded the minds',
#  'chosen the poor of this world rich in faith, and',
#  'saying, the kingdoms of this world are become the kingdoms']

# %%
# let's see how many instances of the phrase "this world" were found
len(concordance)
# Out:
# 13

# %% [markdown]
# Let's try again, but this time let's just search for "world" by itself, not "this world".

# %%
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['and he hath set the world upon them.  2:9',
#  'appeared, the foundations of the world were discovered, at the',
#  'him, all the earth: the world also shall be stable,',
#  'upon the face of the world in the earth. ',
#  'and he shall judge the world in righteousness, he shall',
#  'and the foundations of the world were discovered at thy',
#  'all the ends of the world shall remember and turn',
#  'all the inhabitants of the world stand in awe of',
#  'not tell thee: for the world is mine, and the',
#  'is thine: as for the world and the fulness thereof,',
#  'he hath girded himself: the world also is stablished, that',
#  'that the lord reigneth: the world also shall be established',
#  'earth: he shall judge the world with righteousness, and the',
#  'also he hath set the world in their heart, so',
#  'and i will punish the world for their evil, and',
#  'kingdoms; 14:17 that made the world as a wilderness, and',
#  'fill the face of the world with cities.  14:22',
#  'all the kingdoms of the world upon the face of',
#  'mourneth and fadeth away, the world languisheth and fadeth away,',
#  'earth, the inhabitants of the world will learn righteousness. ',
#  'have the inhabitants of the world fallen.  26:19 thy',
#  'fill the face of the world with fruit.  27:7',
#  'not be ashamed nor confounded world without end.  45:18',
#  'since the beginning of the world men have not heard,',
#  'power, he hath established the world by his wisdom, and',
#  'power, he hath established the world by his wisdom, and',
#  'this world, neither in the world to come.  12:33',
#  ' 18:7 woe unto the world because of offences! for',
#  'be preached in all the world for a witness unto',
#  'since the beginning of the world to this time, no,',
#  'with persecutions; and in the world to come eternal life.',
#  'which have been since the world began: 1:71 that we',
#  'caesar augustus that all the world should be taxed. ',
#  'all the kingdoms of the world in a moment of',
#  'do the nations of the world seek after: and your',
#  'for the children of this world are in their generation',
#  'present time, and in the world to come life everlasting.',
#  'them, the children of this world marry, and are given',
#  'in the world, and the world was made by him,',
#  'made by him, and the world knew him not. ',
#  'not his son into the world to condemn the world;',
#  'the world; but that the world through him might be',
#  'alway ready.  7:7 the world cannot hate you; but',
#  'and i speak to the world those things which i',
#  'heareth.  9:32 since the world began was it not',
#  'ye prevail nothing? behold, the world is gone after him.',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'spirit of truth; whom the world cannot receive, because it',
#  'a little while, and the world seeth me no more;',
#  'unto you: not as the world giveth, give i unto',
#  'for the prince of this world cometh, and hath nothing',
#  ' 14:31 but that the world may know that i',
#  'another.  15:18 if the world hate you, ye know',
#  'were of the world, the world would love his own:',
#  'of the world, therefore the world hateth you.  15:20',
#  'come, he will reprove the world of sin, and of',
#  'because the prince of this world is judged.  16:12',
#  'weep and lament, but the world shall rejoice: and ye',
#  'have peace.  in the world ye shall have tribulation:',
#  'had with thee before the world was.  17:6 i',
#  'them thy word; and the world hath hated them, because',
#  'one in us: that the world may believe that thou',
#  'in one; and that the world may know that thou',
#  '17:25 o righteous father, the world hath not known thee:',
#  'i suppose that even the world itself could not contain',
#  'his holy prophets since the world began.  3:22 for',
#  'these that have turned the world upside down are come',
#  '17:24 god that made the world and all things therein,',
#  'which he will judge the world in righteousness by that',
#  'whom all asia and the world worshippeth.  19:28 and',
#  'from the creation of the world are clearly seen, being',
#  'be stopped, and all the world may become guilty before',
#  'was kept secret since the world began, 16:26 but now',
#  'the wisdom of god the world by wisdom knew not',
#  'the foolish things of the world to confound the wise;',
#  'the weak things of the world to confound the things',
#  'which god ordained before the world unto our glory: 2:8',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'the world? and if the world shall be judged by',
#  'for the fashion of this world passeth away.  7:32',
#  'eat no flesh while the world standeth, lest i make',
#  'whom the ends of the world are come.  10:12',
#  'whom the god of this world hath blinded the minds',
#  'was in christ, reconciling the world unto himself, not imputing',
#  'but the sorrow of the world worketh death.  7:11',
#  'jesus christ, by whom the world is crucified unto me,',
#  'from the beginning of the world hath been hid in',
#  'christ jesus throughout all ages, world without end. amen. ',
#  'christ jesus came into the world to save sinners; of',
#  'in christ jesus before the world began, 1:10 but is',
#  'cannot lie, promised before the world began; 1:3 but hath',
#  'not put in subjection the world to come, whereof we',
#  'and the powers of the world to come, 6:6 if',
#  'in the end of the world hath he appeared to',
#  'tormented; 11:38 (of whom the world was not worthy:) they',
#  'chosen the poor of this world rich in faith, and',
#  'tongue is a fire, a world of iniquity: so is',
#  'that the friendship of the world is enmity with god?',
#  'be a friend of the world is the enemy of',
#  'corruption that is in the world through lust.  1:5',
#  'in the flood upon the world of the ungodly; 2:6',
#  'escaped the pollutions of the world through the knowledge of',
#  'the water: 3:6 whereby the world that then was, being',
#  'world.  2:17 and the world passeth away, and the',
#  'sons of god: therefore the world knoweth us not, because',
#  'not, my brethren, if the world hate you.  3:14',
#  'of the world, and the world heareth them.  4:6',
#  'of god, and the whole world lieth in wickedness. ',
#  'saying, the kingdoms of this world are become the kingdoms',
#  'was healed: and all the world wondered after the beast.']

# %%
# let's see how many instances of just the word "world" were found
len(concordance)
# Out:
# 113

# %% [markdown]
# Now, in the cell below, modify the code to search for a different word.

# %%
# add your modified code here and run the cell...
concordance = []
for i, val in enumerate(bible):
    if val == "jesus":
        concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# my own attempt 

concordance
# Out:
# ['book of the generation of jesus christ, the son of',
#  '1:18 now the birth of jesus christ was on this',
#  'jesus.  2:1 now when jesus was born in bethlehem',
#  'fire.  3:13 then cometh jesus from galilee to jordan',
#  'to me?  3:15 and jesus answering said unto him,',
#  'pleased.  4:1 then was jesus led up of the',
#  'against a stone.  4:7 jesus said unto him, it',
#  'me.  4:10 then saith jesus unto him, get thee',
#  'him.  4:12 now when jesus had heard that john',
#  ' 4:17 from that time jesus began to preach, and',
#  'followed him.  4:23 and jesus went about all galilee,',
#  'it came to pass, when jesus had ended these sayings,',
#  'me clean.  8:3 and jesus put forth his hand,',
#  'was cleansed.  8:4 and jesus saith unto him, see',
#  'them.  8:5 and when jesus was entered into capernaum,',
#  'grievously tormented.  8:7 and jesus saith unto him, i',
#  'doeth it.  8:10 when jesus heard it, he marvelled,',
#  'of teeth.  8:13 and jesus said unto the centurion,',
#  "hour.  8:14 and when jesus was come into peter's",
#  'sicknesses.  8:18 now when jesus saw great multitudes about',
#  'thou goest.  8:20 and jesus saith unto him, the',
#  'my father.  8:22 but jesus said unto him, follow',
#  'lying on a bed: and jesus seeing their faith said',
#  'man blasphemeth.  9:4 and jesus knowing their thoughts said,',
#  'men.  9:9 and as jesus passed forth from thence,',
#  'it came to pass, as jesus sat at meat in',
#  'sinners?  9:12 but when jesus heard that, he said',
#  'fast not?  9:15 and jesus said unto them, can',
#  'shall live.  9:19 and jesus arose, and followed him,',
#  'be whole.  9:22 but jesus turned him about, and',
#  "hour.  9:23 and when jesus came into the ruler's",
#  'land.  9:27 and when jesus departed thence, two blind',
#  'men came to him: and jesus saith unto them, believe',
#  'their eyes were opened; and jesus straitly charged them, saying,',
#  'the devils.  9:35 and jesus went about all the',
#  'him.  10:5 these twelve jesus sent forth, and commanded',
#  'it came to pass, when jesus had made an end',
#  'look for another?  11:4 jesus answered and said unto',
#  '11:7 and as they departed, jesus began to say unto',
#  ' 11:25 at that time jesus answered and said, i',
#  ' 12:1 at that time jesus went on the sabbath',
#  'him.  12:15 but when jesus knew it, he withdrew',
#  'the devils.  12:25 and jesus knew their thoughts, and',
#  '13:1 the same day went jesus out of the house,',
#  '13:34 all these things spake jesus unto the multitude in',
#  'the world.  13:36 then jesus sent the multitude away,',
#  'gnashing of teeth.  13:51 jesus saith unto them, have',
#  'came to pass, that when jesus had finished these parables,',
#  'were offended in him. but jesus said unto them, a',
#  'told jesus.  14:13 when jesus heard of it, he',
#  'the cities.  14:14 and jesus went forth, and saw',
#  'themselves victuals.  14:16 but jesus said unto them, they',
#  'children.  14:22 and straightway jesus constrained his disciples to',
#  'fourth watch of the night jesus went unto them, walking',
#  'fear.  14:27 but straightway jesus spake unto them, saying,',
#  'me.  14:31 and immediately jesus stretched forth his hand,',
#  ' 15:1 then came to jesus scribes and pharisees, which',
#  'this parable.  15:16 and jesus said, are ye also',
#  'a man.  15:21 then jesus went thence, and departed',
#  "masters' table.  15:28 then jesus answered and said unto",
#  'very hour.  15:29 and jesus departed from thence, and',
#  'of israel.  15:32 then jesus called his disciples unto',
#  'a multitude?  15:34 and jesus saith unto them, how',
#  'take bread.  16:6 then jesus said unto them, take',
#  'bread.  16:8 which when jesus perceived, he said unto',
#  'the sadducees.  16:13 when jesus came into the coasts',
#  'living god.  16:17 and jesus answered and said unto',
#  'no man that he was jesus the christ.  16:21',
#  'from that time forth began jesus to shew unto his',
#  'men.  16:24 then said jesus unto his disciples, if',
#  '17:1 and after six days jesus taketh peter, james, and',
#  'sore afraid.  17:7 and jesus came and touched them,',
#  'they saw no man, save jesus only.  17:9 and',
#  'came down from the mountain, jesus charged them, saying, tell',
#  'first come?  17:11 and jesus answered and said unto',
#  'cure him.  17:17 then jesus answered and said, o',
#  'to me.  17:18 and jesus rebuked the devil; and',
#  'then came the disciples to jesus apart, and said, why',
#  'him out?  17:20 and jesus said unto them, because',
#  'while they abode in galilee, jesus said unto them, the',
#  'was come into the house, jesus prevented him, saying, what',
#  'saith unto him, of strangers. jesus saith unto him, then',
#  'of heaven?  18:2 and jesus called a little child',
#  'till seven times?  18:22 jesus saith unto him, i',
#  'came to pass, that when jesus had finished these sayings,',
#  'rebuked them.  19:14 but jesus said, suffer little children,',
#  'he saith unto him, which? jesus said, thou shalt do',
#  'lack i yet?  19:21 jesus said unto him, if',
#  'possessions.  19:23 then said jesus unto his disciples, verily',
#  'be saved?  19:26 but jesus beheld them, and said',
#  'have therefore?  19:28 and jesus said unto them, verily',
#  'few chosen.  20:17 and jesus going up to jerusalem',
#  'thy kingdom.  20:22 but jesus answered and said, ye',
#  'two brethren.  20:25 but jesus called them unto him,',
#  'side, when they heard that jesus passed by, cried out,',
#  'of david.  20:32 and jesus stood still, and called',
#  'be opened.  20:34 so jesus had compassion on them,',
#  'mount of olives, then sent jesus two disciples, 21:2 saying',
#  'disciples went, and did as jesus commanded them, 21:7 and',
#  'the multitude said, this is jesus the prophet of nazareth',
#  'of galilee.  21:12 and jesus went into the temple',
#  'thou what these say? and jesus saith unto them, yea;',
#  'tree withered away!  21:21 jesus answered and said unto',
#  'this authority?  21:24 and jesus answered and said unto',
#  'say unto him, the first. jesus saith unto them, verily',
#  'in their seasons.  21:42 jesus saith unto them, did',
#  'a prophet.  22:1 and jesus answered and spake unto',
#  'or not?  22:18 but jesus perceived their wickedness, and',
#  'all had her.  22:29 jesus answered and said unto',
#  'in the law?  22:37 jesus said unto him, thou',
#  'the pharisees were gathered together, jesus asked them, 22:42 saying,',
#  'questions.  23:1 then spake jesus to the multitude, and',
#  'the lord.  24:1 and jesus went out, and departed',
#  'the temple.  24:2 and jesus said unto them, see',
#  'the world?  24:4 and jesus answered and said unto',
#  'it came to pass, when jesus had finished all these',
#  'consulted that they might take jesus by subtilty, and kill',
#  'people.  26:6 now when jesus was in bethany, in',
#  'the poor.  26:10 when jesus understood it, he said',
#  'and the disciples did as jesus had appointed them; and',
#  'and as they were eating, jesus took bread, and blessed',
#  'olives.  26:31 then saith jesus unto them, all ye',
#  'never be offended.  26:34 jesus said unto him, verily',
#  'disciples.  26:36 then cometh jesus with them unto a',
#  'kissed him.  26:50 and jesus said unto him, friend,',
#  'they, and laid hands on jesus and took him. ',
#  'of them which were with jesus stretched out his hand,',
#  'ear.  26:52 then said jesus unto him, put up',
#  'in that same hour said jesus to the multitudes, are',
#  'that had laid hold on jesus led him away to',
#  'against thee?  26:63 but jesus held his peace, and',
#  'son of god.  26:64 jesus saith unto him, thou',
#  'saying, thou also wast with jesus of galilee.  26:70',
#  'this fellow was also with jesus of nazareth.  26:72',
#  'the people took counsel against jesus to put him to',
#  'appointed me.  27:11 and jesus stood before the governor:',
#  'king of the jews? and jesus said unto him, thou',
#  'release unto you? barabbas, or jesus which is called christ?',
#  'shall i do then with jesus which is called christ?',
#  'soldiers of the governor took jesus into the common hall,',
#  'his accusation written, this is jesus the king of the',
#  'and about the ninth hour jesus cried with a loud',
#  'beholding afar off, which followed jesus from galilee, ministering unto',
#  'to tell his disciples, behold, jesus met them, saying, all',
#  'him.  28:10 then said jesus unto them, be not',
#  'galilee, into a mountain where jesus had appointed them. ',
#  'some doubted.  28:18 and jesus came and spake unto',
#  'beginning of the gospel of jesus christ, the son of',
#  'pass in those days, that jesus came from nazareth of',
#  'john was put in prison, jesus came into galilee, preaching',
#  'were fishers.  1:17 and jesus said unto them, come',
#  'to do with thee, thou jesus of nazareth? art thou',
#  'of god.  1:25 and jesus rebuked him, saying, hold',
#  'abroad the matter, insomuch that jesus could no more openly',
#  'palsy lay.  2:5 when jesus saw their faith, he',
#  ' 2:8 and immediately when jesus perceived in his spirit',
#  'came to pass, that, as jesus sat at meat in',
#  'sinners sat also together with jesus and his disciples: for',
#  'and sinners?  2:17 when jesus heard it, he saith',
#  'fast not?  2:19 and jesus said unto them, can',
#  'destroy him.  3:7 but jesus withdrew himself with his',
#  '5:6 but when he saw jesus afar off, he ran',
#  'them.  5:13 and forthwith jesus gave them leave. and',
#  'with him.  5:19 howbeit jesus suffered him not, but',
#  'in decapolis how great things jesus had done for him:',
#  'marvel.  5:21 and when jesus was passed over again',
#  'shall live.  5:24 and jesus went with him; and',
#  ' 5:36 as soon as jesus heard the word that',
#  'her daughter.  7:27 but jesus said unto her, let',
#  'and having nothing to eat, jesus called his disciples unto',
#  'bread.  8:17 and when jesus knew it, he saith',
#  'the town.  8:27 and jesus went out, and his',
#  '9:2 and after six days jesus taketh with him peter,',
#  'no man any more, save jesus only with themselves. ',
#  'and help us.  9:23 jesus said unto him, if',
#  'mine unbelief.  9:25 when jesus saw that the people',
#  'is dead.  9:27 but jesus took him by the',
#  'not us.  9:39 but jesus said, forbid him not:',
#  'her away.  10:5 and jesus answered and said unto',
#  'them.  10:14 but when jesus saw it, he was',
#  'eternal life?  10:18 and jesus said unto him, why',
#  'my youth.  10:21 then jesus beholding him loved him,',
#  'great possessions.  10:23 and jesus looked round about, and',
#  'astonished at his words. but jesus answereth again, and saith',
#  'be saved?  10:27 and jesus looking upon them saith,',
#  'followed thee.  10:29 and jesus answered and said, verily',
#  'going up to jerusalem; and jesus went before them: and',
#  'thy glory.  10:38 but jesus said unto them, ye',
#  'unto him, we can. and jesus said unto them, ye',
#  'and john.  10:42 but jesus called them to him,',
#  'he heard that it was jesus of nazareth, he began',
#  'on me.  10:49 and jesus stood still, and commanded',
#  'to jesus.  10:51 and jesus answered and said unto',
#  'my sight.  10:52 and jesus said unto him, go',
#  'received his sight, and followed jesus in the way. ',
#  'said unto them even as jesus had commanded: and they',
#  'the highest.  11:11 and jesus entered into jerusalem, and',
#  'not yet.  11:14 and jesus answered and said unto',
#  'they come to jerusalem: and jesus went into the temple,',
#  'withered away.  11:22 and jesus answering saith unto them,',
#  'these things?  11:29 and jesus answered and said unto',
#  'jesus, we cannot tell. and jesus answering saith unto them,',
#  "him, caesar's.  12:17 and jesus answering said unto them,",
#  'to wife.  12:24 and jesus answering said unto them,',
#  'of all?  12:29 and jesus answered him, the first',
#  'sacrifices.  12:34 and when jesus saw that he answered',
#  'any question.  12:35 and jesus answered and said, while',
#  'greater damnation.  12:41 and jesus sat over against the',
#  'buildings are here! 13:2 and jesus answering said unto him,',
#  'be fulfilled?  13:5 and jesus answering them began to',
#  'against her.  14:6 and jesus said, let her alone;',
#  'they sat and did eat, jesus said, verily i say',
#  'and as they did eat, jesus took bread, and blessed,',
#  'of olives.  14:27 and jesus saith unto them, all',
#  'not i.  14:30 and jesus saith unto him, verily',
#  'his ear.  14:48 and jesus answered and said unto',
#  ' 14:53 and they led jesus away to the high',
#  'council sought for witness against jesus to put him to',
#  'the blessed?  14:62 and jesus said, i am: and',
#  'and thou also wast with jesus of nazareth.  14:68',
#  'to mind the word that jesus said unto him, before',
#  'against thee.  15:5 but jesus yet answered nothing; so',
#  'and at the ninth hour jesus cried with a loud',
#  'him down.  15:37 and jesus cried with a loud',
#  'be not affrighted: ye seek jesus of nazareth, which was',
#  'afraid.  16:9 now when jesus was risen early the',
#  'as they returned, the child jesus tarried behind in jerusalem;',
#  'her heart.  2:52 and jesus increased in wisdom and',
#  'it came to pass, that jesus also being baptized, and',
#  'well pleased.  3:23 and jesus himself began to be',
#  'of god.  4:1 and jesus being full of the',
#  'made bread.  4:4 and jesus answered him, saying, it',
#  'be thine.  4:8 and jesus answered and said unto',
#  'a stone.  4:12 and jesus answering said unto him,',
#  'a season.  4:14 and jesus returned in the power',
#  'to do with thee, thou jesus of nazareth? art thou',
#  'of god.  4:35 and jesus rebuked him, saying, hold',
#  'were partners with simon. and jesus said unto simon, fear',
#  'full of leprosy: who seeing jesus fell on his face,',
#  'god alone? 5:22 but when jesus perceived their thoughts, he',
#  'and sinners?  5:31 and jesus answering said unto them,',
#  'sabbath days?  6:3 and jesus answering them said, have',
#  'forth.  6:9 then said jesus unto them, i will',
#  'a synagogue.  7:6 then jesus went with them. and',
#  'doeth it.  7:9 when jesus heard these things, he',
#  'gave sight.  7:22 then jesus answering said unto them,',
#  'sinner, when she knew that jesus sat at meat in',
#  'a sinner.  7:40 and jesus answering said unto him,',
#  'the wilderness.)  8:30 and jesus asked him, saying, what',
#  'might be with him: but jesus sent him away, saying,',
#  'whole city how great things jesus had done unto him.',
#  'came to pass, that, when jesus was returned, the people',
#  'blood stanched.  8:45 and jesus said, who touched me?',
#  'touched me?  8:46 and jesus said, somebody hath touched',
#  'master.  8:50 but when jesus heard it, he answered',
#  'when the voice was past, jesus was found alone. and',
#  'could not.  9:41 and jesus answering said, o faithless',
#  'and tare him.  and jesus rebuked the unclean spirit,',
#  'one at all things which jesus did, he said unto',
#  'with us.  9:50 and jesus said unto him, forbid',
#  'thou goest.  9:58 and jesus said unto him, foxes',
#  'bury my father.  9:60 jesus said unto him, let',
#  'my house.  9:62 and jesus said unto him, no',
#  ' 10:21 in that hour jesus rejoiced in spirit, and',
#  'my neighbour?  10:30 and jesus answering said, a certain',
#  'mercy on him. then said jesus unto him, go, and',
#  'help me.  10:41 and jesus answered and said unto',
#  'their sacrifices.  13:2 and jesus answering said unto them,',
#  'herself.  13:12 and when jesus saw her, he called',
#  'answered with indignation, because that jesus had healed on the',
#  'the dropsy.  14:3 and jesus answering spake unto the',
#  'a samaritan.  17:17 and jesus answering said, were there',
#  'rebuked them.  18:16 but jesus called them unto him,',
#  'eternal life?  18:19 and jesus said unto him, why',
#  'up.  18:22 now when jesus heard these things, he',
#  'rich.  18:24 and when jesus saw that he was',
#  'and they told him, that jesus of nazareth passeth by.',
#  'on me.  18:40 and jesus stood, and commanded him',
#  'my sight.  18:42 and jesus said unto him, receive',
#  'unto god.  19:1 and jesus entered and passed through',
#  'and he sought to see jesus who he was; and',
#  'way.  19:5 and when jesus came to the place,',
#  'him fourfold.  19:9 and jesus said unto him, this',
#  'the colt, and they set jesus thereon.  19:36 and',
#  'it was.  20:8 and jesus said unto them, neither',
#  'to wife.  20:34 and jesus answering said unto them,',
#  'them, and drew near unto jesus to kiss him. ',
#  'kiss him.  22:48 but jesus said unto him, judas,',
#  'right ear.  22:51 and jesus answered and said, suffer',
#  'healed him.  22:52 then jesus said unto the chief',
#  'and the men that held jesus mocked him, and smote',
#  'had desired; but he delivered jesus to their will. ',
#  'lamented him.  23:28 but jesus turning unto them said,',
#  'thy kingdom.  23:43 and jesus said unto him, verily',
#  'midst.  23:46 and when jesus had cried with a',
#  'they communed together and reasoned, jesus himself drew near, and',
#  'they said unto him, concerning jesus of nazareth, which was',
#  'and as they thus spake, jesus himself stood in the',
#  'grace and truth came by jesus christ.  1:18 no',
#  'the next day john seeth jesus coming unto him, and',
#  'disciples; 1:36 and looking upon jesus as he walked, he',
#  'followed jesus.  1:38 then jesus turned, and saw them',
#  'him to jesus. and when jesus beheld him, he said,',
#  ' 1:43 the day following jesus would go forth into',
#  'and the prophets, did write, jesus of nazareth, the son',
#  'come and see.  1:47 jesus saw nathanael coming to',
#  'him, whence knowest thou me? jesus answered and said unto',
#  'king of israel.  1:50 jesus answered and said unto',
#  'galilee; and the mother of jesus was there: 2:2 and',
#  'was there: 2:2 and both jesus was called, and his',
#  'wanted wine, the mother of jesus saith unto him, they',
#  'have no wine.  2:4 jesus saith unto her, woman,',
#  'three firkins apiece.  2:7 jesus saith unto them, fill',
#  'this beginning of miracles did jesus in cana of galilee,',
#  'passover was at hand, and jesus went up to jerusalem.',
#  'doest these things?  2:19 jesus answered and said unto',
#  'scripture, and the word which jesus had said.  2:23',
#  'he did.  2:24 but jesus did not commit himself',
#  '3:2 the same came to jesus by night, and said',
#  'be with him.  3:3 jesus answered and said unto',
#  'and be born?  3:5 jesus answered, verily, verily, i',
#  'can these things be? 3:10 jesus answered and said unto',
#  '3:22 after these things came jesus and his disciples into',
#  'the pharisees had heard that jesus made and baptized more',
#  'disciples than john, 4:2 (though jesus himself baptized not, but',
#  "now jacob's well was there. jesus therefore, being wearied with",
#  'of samaria to draw water: jesus saith unto her, give',
#  'with the samaritans.  4:10 jesus answered and said unto',
#  'and his cattle?  4:13 jesus answered and said unto',
#  'hither to draw.  4:16 jesus saith unto her, go,',
#  'said, i have no husband. jesus said unto her, thou',
#  'ought to worship.  4:21 jesus saith unto her, woman,',
#  'us all things.  4:26 jesus saith unto her, i',
#  'ought to eat?  4:34 jesus saith unto them, my',
#  'into galilee.  4:44 for jesus himself testified, that a',
#  'the feast.  4:46 so jesus came again into cana',
#  '4:47 when he heard that jesus was come out of',
#  'death.  4:48 then said jesus unto him, except ye',
#  'my child die.  4:50 jesus saith unto him, go',
#  'man believed the word that jesus had spoken unto him,',
#  'same hour, in the which jesus said unto him, thy',
#  'again the second miracle that jesus did, when he was',
#  'feast of the jews; and jesus went up to jerusalem.',
#  'eight years.  5:6 when jesus saw him lie, and',
#  'down before me.  5:8 jesus saith unto him, rise,',
#  'not who it was: for jesus had conveyed himself away,',
#  'that place.  5:14 afterward jesus findeth him in the',
#  'sabbath day.  5:17 but jesus answered them, my father',
#  'god.  5:19 then answered jesus and said unto them,',
#  ' 6:1 after these things jesus went over the sea',
#  'were diseased.  6:3 and jesus went up into a',
#  'was nigh.  6:5 when jesus then lifted up his',
#  'so many?  6:10 and jesus said, make the men',
#  'five thousand.  6:11 and jesus took the loaves; and',
#  'had seen the miracle that jesus did, said, this is',
#  'the world.  6:15 when jesus therefore perceived that they',
#  'it was now dark, and jesus was not come to',
#  'or thirty furlongs, they see jesus walking on the sea,',
#  'disciples were entered, and that jesus went not with his',
#  'the people therefore saw that jesus was not there, neither',
#  'camest thou hither?  6:26 jesus answered them and said,',
#  'works of god?  6:29 jesus answered and said unto',
#  'to eat.  6:32 then jesus said unto them, verily,',
#  'this bread.  6:35 and jesus said unto them, i',
#  'down from heaven?  6:43 jesus therefore answered and said',
#  'to eat?  6:53 then jesus said unto them, verily,',
#  'hear it?  6:61 when jesus knew in himself that',
#  'you that believe not. for jesus knew from the beginning',
#  'him.  6:67 then said jesus unto the twelve, will',
#  'the living god.  6:70 jesus answered them, have not',
#  ' 7:1 after these things jesus walked in galilee: for',
#  'in him.  7:6 then jesus said unto them, my',
#  'the midst of the feast jesus went up into the',
#  'having never learned?  7:16 jesus answered them, and said,',
#  'to kill thee?  7:21 jesus answered and said unto',
#  'is.  7:28 then cried jesus in the temple as',
#  'him.  7:33 then said jesus unto them, yet a',
#  'great day of the feast, jesus stood and cried, saying,',
#  'not yet given; because that jesus was not yet glorified.)',
#  'them, (he that came to jesus by night, being one',
#  'his own house.  8:1 jesus went unto the mount',
#  'have to accuse him. but jesus stooped down, and with',
#  'even unto the last: and jesus was left alone, and',
#  'the midst.  8:10 when jesus had lifted up himself,',
#  'said, no man, lord. and jesus said unto her, neither',
#  'more.  8:12 then spake jesus again unto them, saying,',
#  'is not true.  8:14 jesus answered and said unto',
#  'him, where is thy father? jesus answered, ye neither know',
#  ' 8:20 these words spake jesus in the treasury, as',
#  'come.  8:21 then said jesus again unto them, i',
#  'him, who art thou? and jesus saith unto them, even',
#  'father.  8:28 then said jesus unto them, when ye',
#  'him.  8:31 then said jesus to those jews which',
#  'be made free?  8:34 jesus answered them, verily, verily,',
#  'him, abraham is our father. jesus saith unto them, if',
#  'father, even god.  8:42 jesus said unto them, if',
#  'hast a devil?  8:49 jesus answered, i have not',
#  'makest thou thyself?  8:54 jesus answered, if i honour',
#  'thou seen abraham?  8:58 jesus said unto them, verily,',
#  'to cast at him: but jesus hid himself, and went',
#  'by.  9:1 and as jesus passed by, he saw',
#  'was born blind?  9:3 jesus answered, neither hath this',
#  'a man that is called jesus made clay, and anointed',
#  'was the sabbath day when jesus made the clay, and',
#  'cast him out.  9:35 jesus heard that they had',
#  'on him?  9:37 and jesus said unto him, thou',
#  'worshipped him.  9:39 and jesus said, for judgment i',
#  'we blind also?  9:41 jesus said unto them, if',
#  ' 10:6 this parable spake jesus unto them: but they',
#  'them.  10:7 then said jesus unto them again, verily,',
#  'was winter.  10:23 and jesus walked in the temple',
#  'tell us plainly.  10:25 jesus answered them, i told',
#  'to stone him.  10:32 jesus answered them, many good',
#  'makest thyself god.  10:34 jesus answered them, is it',
#  'is sick.  11:4 when jesus heard that, he said,',
#  'glorified thereby.  11:5 now jesus loved martha, and her',
#  'thou thither again?  11:9 jesus answered, are there not',
#  'do well.  11:13 howbeit jesus spake of his death:',
#  'sleep.  11:14 then said jesus unto them plainly, lazarus',
#  'him.  11:17 then when jesus came, he found that',
#  'soon as she heard that jesus was coming, went and',
#  'give it thee.  11:23 jesus saith unto her, thy',
#  'the last day.  11:25 jesus said unto her, i',
#  'unto him.  11:30 now jesus was not yet come',
#  'when mary was come where jesus was, and saw him,',
#  'not died.  11:33 when jesus therefore saw her weeping,',
#  'come and see.  11:35 jesus wept.  11:36 then',
#  'not have died?  11:38 jesus therefore again groaning in',
#  'lay upon it.  11:39 jesus said, take ye away',
#  'dead four days.  11:40 jesus saith unto her, said',
#  'the dead was laid. and jesus lifted up his eyes,',
#  'bound about with a napkin. jesus saith unto them, loose',
#  'had seen the things which jesus did, believed on him.',
#  'and told them what things jesus had done.  11:47',
#  'that year, he prophesied that jesus should die for that',
#  'him to death.  11:54 jesus therefore walked no more',
#  'take him.  12:1 then jesus six days before the',
#  'feast, when they heard that jesus was coming to jerusalem,',
#  'at the first: but when jesus was glorified, then remembered',
#  'tell jesus.  12:23 and jesus answered them, saying, the',
#  'spake to him.  12:30 jesus answered and said, this',
#  'of man?  12:35 then jesus said unto them, yet',
#  'praise of god.  12:44 jesus cried and said, he',
#  'feast of the passover, when jesus knew that his hour',
#  'son, to betray him; 13:3 jesus knowing that the father',
#  'wash my feet?  13:7 jesus answered and said unto',
#  'shalt never wash my feet. jesus answered him, if i',
#  'and my head.  13:10 jesus saith to him, he',
#  'sent me.  13:21 when jesus had thus said, he',
#  'one of his disciples, whom jesus loved.  13:24 simon',
#  'lord, who is it? 13:26 jesus answered, he it is,',
#  'entered into him. then said jesus unto him, that thou',
#  'judas had the bag, that jesus had said unto him,',
#  'when he was gone out, jesus said, now is the',
#  'him, lord, whither goest thou? jesus answered him, whither i',
#  'for thy sake.  13:38 jesus answered him, wilt thou',
#  'know the way?  14:6 jesus saith unto him, i',
#  'it sufficeth us.  14:9 jesus saith unto him, have',
#  'unto the world?  14:23 jesus answered and said unto',
#  'he saith.  16:19 now jesus knew that they were',
#  'forth from god.  16:31 jesus answered them, do ye',
#  'the only true god, and jesus christ, whom thou hast',
#  'in them.  18:1 when jesus had spoken these words,',
#  'him, knew the place: for jesus ofttimes resorted thither with',
#  'torches and weapons.  18:4 jesus therefore, knowing all things',
#  ' 18:5 they answered him, jesus of nazareth. jesus saith',
#  'answered him, jesus of nazareth. jesus saith unto them, i',
#  'seek ye? and they said, jesus of nazareth.  18:8',
#  'jesus of nazareth.  18:8 jesus answered, i have told',
#  'malchus.  18:11 then said jesus unto peter, put up',
#  'priest, and went in with jesus into the palace of',
#  'the high priest then asked jesus of his disciples, and',
#  'of his doctrine.  18:20 jesus answered him, i spake',
#  'officers which stood by struck jesus with the palm of',
#  'high priest so?  18:23 jesus answered him, if i',
#  ' 18:28 then led they jesus from caiaphas unto the',
#  '18:32 that the saying of jesus might be fulfilled, which',
#  'of the jews?  18:34 jesus answered him, sayest thou',
#  'what hast thou done? 18:36 jesus answered, my kingdom is',
#  'art thou a king then? jesus answered, thou sayest that',
#  'him.  19:5 then came jesus forth, wearing the crown',
#  'jesus, whence art thou? but jesus gave him no answer.',
#  'to release thee?  19:11 jesus answered, thou couldest have',
#  'heard that saying, he brought jesus forth, and sat down',
#  'on either side one, and jesus in the midst. ',
#  'cross. and the writing was jesus of nazareth the king',
#  'jews: for the place where jesus was crucified was nigh',
#  'stood by the cross of jesus his mother, and his',
#  'mary magdalene.  19:26 when jesus therefore saw his mother,',
#  'home.  19:28 after this, jesus knowing that all things',
#  'his mouth.  19:30 when jesus therefore had received the',
#  'at the first came to jesus by night, and brought',
#  ' 19:42 there laid they jesus therefore because of the',
#  'to the other disciple, whom jesus loved, and saith unto',
#  'feet, where the body of jesus had lain.  20:13',
#  'turned herself back, and saw jesus standing, and knew not',
#  'it was jesus.  20:15 jesus saith unto her, woman,',
#  'take him away.  20:16 jesus saith unto her, mary.',
#  'to say, master.  20:17 jesus saith unto her, touch',
#  'fear of the jews, came jesus and stood in the',
#  'lord.  20:21 then said jesus to them again, peace',
#  'was not with them when jesus came.  20:25 the',
#  'and my god.  20:29 jesus saith unto him, thomas,',
#  'many other signs truly did jesus in the presence of',
#  'that ye might believe that jesus is the christ, the',
#  ' 21:1 after these things jesus shewed himself again to',
#  'the morning was now come, jesus stood on the shore:',
#  'was jesus.  21:5 then jesus saith unto them, children,',
#  '21:7 therefore that disciple whom jesus loved saith unto peter,',
#  'thereon, and bread.  21:10 jesus saith unto them, bring',
#  'the net broken.  21:12 jesus saith unto them, come',
#  'was the lord.  21:13 jesus then cometh, and taketh',
#  'now the third time that jesus shewed himself to his',
#  'so when they had dined, jesus saith to simon peter,',
#  'knowest that i love thee. jesus saith unto him, feed',
#  'about, seeth the disciple whom jesus loved following; which also',
#  'this man do?  21:22 jesus saith unto him, if',
#  'disciple should not die: yet jesus said not unto him,',
#  'also many other things which jesus did, the which, if',
#  'o theophilus, of all that jesus began both to do',
#  'the time that the lord jesus went in and out',
#  'of israel, hear these words; jesus of nazareth, a man',
#  'see corruption.  2:32 this jesus hath god raised up,',
#  'you in the name of jesus christ for the remission',
#  'thee: in the name of jesus christ of nazareth rise',
#  '3:20 and he shall send jesus christ, which before was',
#  'the people, and preached through jesus the resurrection from the',
#  'that by the name of jesus christ of nazareth, whom',
#  'not to teach and preach jesus christ.  6:1 and',
#  'heard him say, that this jesus of nazareth shall destroy',
#  'came after brought in with jesus into the possession of',
#  'the glory of god, and jesus standing on the right',
#  'god, and the name of jesus christ, they were baptized,',
#  'and said, i believe that jesus christ is the son',
#  'the lord said, i am jesus whom thou persecutest: it',
#  'peter said unto him, aeneas, jesus christ maketh thee whole:',
#  'of israel, preaching peace by jesus christ: (he is lord',
#  'preached; 10:38 how god anointed jesus of nazareth with the',
#  'who believed on the lord jesus christ; what was i,',
#  'that he hath raised up jesus again; as it is',
#  'the grace of the lord jesus christ we shall be',
#  'the name of our lord jesus christ.  15:27 we',
#  'thee in the name of jesus christ to come out',
#  'said, believe on the lord jesus christ, and thou shalt',
#  'testified to the jews that jesus was christ.  18:6',
#  'shewing by the scriptures that jesus was christ.  19:1',
#  'saying, we adjure you by jesus whom paul preacheth. ',
#  'evil spirit answered and said, jesus i know, and paul',
#  'the name of the lord jesus was magnified.  19:18',
#  'and faith toward our lord jesus christ.  20:22 and',
#  'said unto me, i am jesus of nazareth, whom thou',
#  'contrary to the name of jesus of nazareth.  26:10',
#  'and he said, i am jesus whom thou persecutest. ',
#  'things which concern the lord jesus christ, with all confidence,',
#  '1:1 paul, a servant of jesus christ, called to be',
#  'scriptures,) 1:3 concerning his son jesus christ our lord, which',
#  'ye also the called of jesus christ: 1:7 to all',
#  'our father, and the lord jesus christ.  1:8 first,',
#  'i thank my god through jesus christ for you all,',
#  'the secrets of men by jesus christ according to my',
#  'which is by faith of jesus christ unto all and',
#  'on him that raised up jesus our lord from the',
#  'with god through our lord jesus christ: 5:2 by whom',
#  'in god through our lord jesus christ, by whom we',
#  'which is by one man, jesus christ, hath abounded unto',
#  'reign in life by one, jesus christ.)  5:18 therefore',
#  'righteousness unto eternal life by jesus christ our lord. ',
#  'us as were baptized into jesus christ were baptized into',
#  'but alive unto god through jesus christ our lord. ',
#  'god is eternal life through jesus christ our lord. ',
#  '7:25 i thank god through jesus christ our lord. so',
#  'spirit of life in christ jesus hath made me free',
#  'of him that raised up jesus from the dead dwell',
#  'god, which is in christ jesus our lord.  9:1',
#  'put ye on the lord jesus christ, and make not',
#  'the father of our lord jesus christ.  15:7 wherefore',
#  '15:8 now i say that jesus christ was a minister',
#  'should be the minister of jesus christ to the gentiles,',
#  'whereof i may glory through jesus christ in those things',
#  "you, brethren, for the lord jesus christ's sake, and for",
#  'such serve not our lord jesus christ, but their own',
#  'the grace of our lord jesus christ be with you.',
#  'the grace of our lord jesus christ be with you',
#  'gospel, and the preaching of jesus christ, according to the',
#  'only wise, be glory through jesus christ for ever. amen.',
#  'to be an apostle of jesus christ through the will',
#  'call upon the name of jesus christ our lord, both',
#  'father, and from the lord jesus christ.  1:4 i',
#  'which is given you by jesus christ; 1:5 that in',
#  'the coming of our lord jesus christ: 1:8 who shall',
#  'the day of our lord jesus christ.  1:9 god',
#  'the fellowship of his son jesus christ our lord. ',
#  'the name of our lord jesus christ, that ye all',
#  'any thing among you, save jesus christ, and him crucified.',
#  'that is laid, which is jesus christ.  3:12 now',
#  'many fathers: for in christ jesus i have begotten you',
#  'the name of our lord jesus christ, when ye are',
#  'the power of our lord jesus christ, 5:5 to deliver',
#  'in him; and one lord jesus christ, by whom are',
#  'free? have i not seen jesus christ our lord? are',
#  'unto you, that the lord jesus the same night in',
#  'the spirit of god calleth jesus accursed: and that no',
#  'no man can say that jesus is the lord, but',
#  'which i have in christ jesus our lord, i die',
#  'the victory through our lord jesus christ.  15:58 therefore,',
#  'man love not the lord jesus christ, let him be',
#  'the grace of our lord jesus christ be with you.',
#  '1:1 paul, an apostle of jesus christ by the will',
#  'father, and from the lord jesus christ.  1:3 blessed',
#  'the father of our lord jesus christ, the father of',
#  'for the son of god, jesus christ, who was preached',
#  'preach not ourselves, but christ jesus the lord; and ourselves',
#  'god in the face of jesus christ.  4:7 but',
#  'that the life also of jesus might be made manifest',
#  'that the life also of jesus might be made manifest',
#  'which raised up the lord jesus shall raise up us',
#  'reconciled us to himself by jesus christ, and hath given',
#  'the grace of our lord jesus christ, that, though he',
#  'and father of our lord jesus christ, which is blessed',
#  'your own selves, how that jesus christ is in you,',
#  'the grace of the lord jesus christ, and the love',
#  'neither by man, but by jesus christ, and god the',
#  'father, and from our lord jesus christ, 1:4 who gave',
#  'but by the revelation of jesus christ.  1:13 for',
#  'but by the faith of jesus christ, even we have',
#  'even we have believed in jesus christ, that we might',
#  'the truth, before whose eyes jesus christ hath been evidently',
#  'come on the gentiles through jesus christ; that we might',
#  'the promise by faith of jesus christ might be given',
#  'faith.  5:6 for in jesus christ neither circumcision availeth',
#  'the cross of our lord jesus christ, by whom the',
#  ' 6:15 for in christ jesus neither circumcision availeth any',
#  'the grace of our lord jesus christ be with your',
#  '1:1 paul, an apostle of jesus christ by the will',
#  'father, and from the lord jesus christ.  1:3 blessed',
#  'and father of our lord jesus christ, who hath blessed',
#  'the adoption of children by jesus christ to himself, according',
#  'the god of our lord jesus christ, the father of',
#  'his workmanship, created in christ jesus unto good works, which',
#  '2:13 but now in christ jesus ye who sometimes were',
#  'of the apostles and prophets, jesus christ himself being the',
#  'i paul, the prisoner of jesus christ for you gentiles,',
#  'who created all things by jesus christ: 3:10 to the',
#  'which he purposed in christ jesus our lord: 3:12 in',
#  'the father of our lord jesus christ, 3:15 of whom',
#  'in the church by christ jesus throughout all ages, world',
#  'the name of our lord jesus christ; 5:21 submitting yourselves',
#  'the father and the lord jesus christ.  6:24 grace',
#  'them that love our lord jesus christ in sincerity. ',
#  'and timotheus, the servants of jesus christ, to all the',
#  'all the saints in christ jesus which are at philippi,',
#  'father, and from the lord jesus christ.  1:3 i',
#  'it until the day of jesus christ: 1:7 even as',
#  'all in the bowels of jesus christ.  1:9 and',
#  'of righteousness, which are by jesus christ, unto the glory',
#  'supply of the spirit of jesus christ, 1:20 according to',
#  'may be more abundant in jesus christ for me by',
#  'that at the name of jesus every knee should bow,',
#  'every tongue should confess that jesus christ is lord, to',
#  'i trust in the lord jesus to send timotheus shortly',
#  "not the things which are jesus christ's.  2:22 but",
#  'of the knowledge of christ jesus my lord: for whom',
#  'for the saviour, the lord jesus christ: 3:21 who shall',
#  'the grace of our lord jesus christ be with you',
#  ' paul, an apostle of jesus christ by the will',
#  'our father and the lord jesus christ.  1:3 ',
#  'the father of our lord jesus christ, praying always for',
#  'ye have therefore received christ jesus the lord, so walk',
#  'father and in the lord jesus christ: grace be unto',
#  'our father, and the lord jesus christ.  1:2 we',
#  'of hope in our lord jesus christ, in the sight',
#  'the presence of our lord jesus christ at his coming?',
#  'our father, and our lord jesus christ, direct our way',
#  'the coming of our lord jesus christ with all his',
#  'for if we believe that jesus died and rose again,',
#  'them also which sleep in jesus will god bring with',
#  'obtain salvation by our lord jesus christ, 5:10 who died',
#  'will of god in christ jesus concerning you.  5:19',
#  'the coming of our lord jesus christ.  5:24 faithful',
#  'the grace of our lord jesus christ be with you.',
#  'our father and the lord jesus christ: 1:2 grace unto',
#  'our father and the lord jesus christ.  1:3 we',
#  'with us, when the lord jesus shall be revealed from',
#  'the gospel of our lord jesus christ: 1:9 who shall',
#  'the name of our lord jesus christ may be glorified',
#  'our god and the lord jesus christ.  2:1 now',
#  'the coming of our lord jesus christ, and by our',
#  'the glory of our lord jesus christ.  2:15 therefore,',
#  ' 2:16 now our lord jesus christ himself, and god,',
#  'the name of our lord jesus christ, that ye withdraw',
#  'and exhort by our lord jesus christ, that with quietness',
#  'the grace of our lord jesus christ be with you',
#  '1:1 paul, an apostle of jesus christ by the commandment',
#  'god our saviour, and lord jesus christ, which is our',
#  'from god our father and jesus christ our lord. ',
#  '1:12 and i thank christ jesus our lord, who hath',
#  'of all acceptation, that christ jesus came into the world',
#  'mercy, that in me first jesus christ might shew forth',
#  'be a good minister of jesus christ, nourished up in',
#  'before god, and the lord jesus christ, and the elect',
#  'the words of our lord jesus christ, and to the',
#  'the appearing of our lord jesus christ: 6:15 which in',
#  '1:1 paul, an apostle of jesus christ by the will',
#  'god the father and christ jesus our lord.  1:3',
#  'was given us in christ jesus before the world began,',
#  'the appearing of our saviour jesus christ, who hath abolished',
#  'as a good soldier of jesus christ.  2:4 no',
#  'things.  2:8 remember that jesus christ of the seed',
#  'salvation which is in christ jesus with eternal glory. ',
#  'will live godly in christ jesus shall suffer persecution. ',
#  'before god, and the lord jesus christ, who shall judge',
#  'brethren.  4:22 the lord jesus christ be with thy',
#  'god, and an apostle of jesus christ, according to the',
#  'the father and the lord jesus christ our saviour. ',
#  'great god and our saviour jesus christ; 2:14 who gave',
#  'shed on us abundantly through jesus christ our saviour; 3:7',
#  '1:1 paul, a prisoner of jesus christ, and timothy our',
#  'our father and the lord jesus christ.  1:4 i',
#  'now also a prisoner of jesus christ.  1:10 i',
#  'the grace of our lord jesus christ be with your',
#  'hearts.  4:8 for if jesus had given them rest,',
#  'is passed into the heavens, jesus the son of god,',
#  '7:22 by so much was jesus made a surety of',
#  'offering of the body of jesus christ once for all.',
#  'before us, 12:2 looking unto jesus the author and finisher',
#  'made perfect, 12:24 and to jesus the mediator of the',
#  'of their conversation.  13:8 jesus christ the same yesterday,',
#  'the camp.  13:12 wherefore jesus also, that he might',
#  'wellpleasing in his sight, through jesus christ; to whom be',
#  'god and of the lord jesus christ, to the twelve',
#  'the faith of our lord jesus christ, the lord of',
#  '1:1 peter, an apostle of jesus christ, to the strangers',
#  'sprinkling of the blood of jesus christ: grace unto you,',
#  'and father of our lord jesus christ, which according to',
#  'hope by the resurrection of jesus christ from the dead,',
#  'glory at the appearing of jesus christ: 1:8 whom having',
#  'you at the revelation of jesus christ; 1:14 as obedient',
#  'sacrifices, acceptable to god by jesus christ.  2:6 wherefore',
#  'god,) by the resurrection of jesus christ: 3:22 who is',
#  'things may be glorified through jesus christ, to whom be',
#  'servant and an apostle of jesus christ, to them that',
#  'of god and our saviour jesus christ: 1:2 grace and',
#  'knowledge of god, and of jesus our lord, 1:3 according',
#  'the knowledge of our lord jesus christ.  1:9 but',
#  'of our lord and saviour jesus christ.  1:12 wherefore',
#  'tabernacle, even as our lord jesus christ hath shewed me.',
#  'and coming of our lord jesus christ, but were eyewitnesses',
#  'of the lord and saviour jesus christ, they are again',
#  'of our lord and saviour jesus christ. to him be',
#  'father, and with his son jesus christ.  1:4 and',
#  'another, and the blood of jesus christ his son cleanseth',
#  'an advocate with the father, jesus christ the righteous: 2:2',
#  'but he that denieth that jesus is the christ? he',
#  'the name of his son jesus christ, and love one',
#  'every spirit that confesseth that jesus christ is come in',
#  'spirit that confesseth not that jesus christ is come in',
#  '4:15 whosoever shall confess that jesus is the son of',
#  ' 5:1 whosoever believeth that jesus is the christ is',
#  'but he that believeth that jesus is the son of',
#  'by water and blood, even jesus christ; not by water',
#  'true, even in his son jesus christ. this is the',
#  'father, and from the lord jesus christ, the son of',
#  'world, who confess not that jesus christ is come in',
#  '1:1 jude, the servant of jesus christ, and brother of',
#  'the father, and preserved in jesus christ, and called: 1:2',
#  'lord god, and our lord jesus christ.  1:5 i',
#  'the apostles of our lord jesus christ; 1:18 how that',
#  'the mercy of our lord jesus christ unto eternal life.',
#  ' 1:1 the revelation of jesus christ, which god gave',
#  'and of the testimony of jesus christ, and of all',
#  'his throne; 1:5 and from jesus christ, who is the',
#  'the kingdom and patience of jesus christ, was in the',
#  'and for the testimony of jesus christ.  1:10 i',
#  'and have the testimony of jesus christ.  13:1 and',
#  'god: for the testimony of jesus is the spirit of',
#  'a lie.  22:16 i jesus have sent mine angel',
#  'the grace of our lord jesus christ be with you']

# %%
# my own attempt 

len(concordance)
# Out:
# 777

# %% [markdown]
# The nltk package has the full text of several other classic books. You can see what they are called by running the command in the cell below:

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# ## Your turn!
#
# Here are a some more things you can try. In each case, I have given you a little bit of starter code to get you going, but the cells will not run without some additional code from you.

# %% [markdown]
# ## Challenge 1: build your own concordance
#
# Pick a different book and a different word, or pair of words. Copy and paste from the code above to write some Python code that searches the book of your choice for the word or pair of words of your choice. Put this code in the cell below. By the way, some of the texts use the characters "\r" for "carriage return" instead of "\n" for "newline". You can remove these the same way that you remove the "\n" characters.

# %%
# add your code to search for a word or pair of words in a different book here

# I create a variable called "moby_dick" which contains the text of ... the book Moby Dick
moby_dick = nltk.corpus.gutenberg.raw('melville-moby_dick.txt')

# make all characters lowercase
moby_dick = moby_dick.lower()

# remove the "\r" characters, which indicate line breaks in the text (newlines)
moby_dick = moby_dick.replace('\r', ' ')

# remove the "\n" characters, which indicate line breaks in the text (newlines)
moby_dick = moby_dick.replace('\n', ' ')

# split up the text into a long list of individual words
moby_dick = moby_dick.split(' ')

# %%
# I make a variable called "concordance_moby", and fill it with every occurrence of the phrase "this whale", and a few words preceeding and following "this whale"
concordance_moby = []
for i, val in enumerate(moby_dick):
    if val == "whale":
        if moby_dick[i-1] == "this":
            concordance_moby.append(str(' '.join(moby_dick[i-5:i+5])))

# %%
# a bit unsure about the words in brackets

concordance_moby
# Out:
# ['(folio), chapter v. (razor-back).--of this whale little is  known',
#  ' his face.  this whale averages some sixteen or',
#  '(octavo), chapter iv. (killer).--of this whale little is  precisely',
#  ' this man and this whale again came  together,',
#  "all beale's drawings of this whale are good, excepting the",
#  "with him, i'll eat this whale  in one mouthful.",
#  "a ship's jib-boom.  this whale is  not dead;",
#  'manner.  but if this whale be a king, he',
#  'inclined plane!  hurrah! this whale carries the  everlasting',
#  ' and as for this whale spout, you might ',
#  'of the fishery,  this whale had become entangled in',
#  'many hours  hence this whale will have gone two']

# %%
len(concordance_moby)
# Out:
# 12

# %%
# trying to find the word "boat"

concordance_moby = []
for i, val in enumerate(moby_dick):
    if val == "boat":
        concordance_moby.append(str(' '.join(moby_dick[i-5:i+5])))

# %%
concordance_moby
# Out:
# ['and tow it with a boat as near the shore',
#  'in the bows of his boat was killed by a',
#  'promotion, it seems--aye, a stove boat will make me an',
#  'nantucket; and come a stove boat and stove body when',
#  'mounting a ship from a boat at sea.  the',
#  'a lifeless form.  the boat soon picked them up.',
#  ' the main-yard there!  boat ahoy!  stand by',
#  '   ship and boat diverged; the cold, damp',
#  'i was in the  boat both times, first and',
#  'tackles and bands of the boat which swung there. ',
#  'which swung there.  this boat had  always been',
#  '  "mr. starbuck! larboard boat there, ahoy! a word',
#  'strength, which periodically started the boat along the water like',
#  'other end  of the boat ahab, with one arm,',
#  'oar as in a thousand boat  lowerings ere the',
#  'were seen simultaneously peaked.  boat and  crew sat',
#  'the extreme stern of the boat where it was also',
#  "not very far distant flask's boat was also lying breathlessly",
#  'only the silence of the boat was at intervals startlingly',
#  'wind, we rushed along; the boat  going with such',
#  'mist; neither  ship nor boat to be seen. ',
#  'litter.  meanwhile the  boat was still booming through',
#  'from astern, while forward the boat seemed striking on a',
#  ' though completely swamped, the boat was nearly unharmed. ',
#  'suspended craft seemed a coral boat grown up  to',
#  'to our  own particular boat was chiefly to be',
#  "50    ahab's boat and crew.  fedallah.",
#  ' of his entering a boat in certain comparatively harmless',
#  'captain ahab to have a boat  actually apportioned to',
#  'he stood up in that boat with his solitary knee',
#  'he would have lowered a boat to board the stranger,',
#  ' and hence as the boat steerer or harpooneer is',
#  'violent pitch of  the boat will often go far',
#  'the gunwale of  the boat which was hoisted up',
#  ' considerable vacancy between the boat and the ship, and',
#  'till of a sudden the boat struck as against a',
#  "the whale's slippery back, the boat righted,  and was",
#  'i swear to beach this boat on yonder  island,',
#  '   "watching the boat till it was fairly',
#  ' just risen beneath the boat from the profundities of',
#  ' the prow of the boat is partially unbroken, and',
#  'in the second engraving, the boat is in the act',
#  ' and causing the slight boat to rock in the',
#  'of  classical engravings of boat hooks, chopping knives, and',
#  '   the first boat we read of, floated',
#  'the stern of  the boat it is spirally coiled',
#  'on the american line-tub, the boat looks as if it',
#  'it were, from the one boat to the  other;',
#  ' other; though the first boat always hovers at hand',
#  'stop there, for the doomed boat would infallibly be dragged',
#  '  before lowering the boat for the chase, the',
#  'is then passed inside the boat again; and some ten',
#  'the whale-line folds the whole boat in its complicated coils,',
#  'being taken out of the boat by  the line,',
#  'of these perils, because the boat is rocking  like',
#  'every oarsman in the strained boat  involuntarily bounced forward',
#  'holding its place.  the boat now flew through the',
#  'the other the air--as the boat churned on through both',
#  'all hands began pulling the boat up to him, while',
#  'him, while  yet the boat was being towed on.',
#  'the word of command, the boat  alternately sterning out',
#  '"pull up!--close to!" and the boat ranged  along the',
#  ' skittishly curvetting about both boat and whale, entangling the',
#  ' for, of course, each boat is  supplied with',
#  "the ship, the  jeroboam's boat by the occasional use",
#  'large rolling wave, the  boat would be pushed some',
#  'a headlong wave shot the boat far ahead, and its',
#  'whale?" demanded ahab, when the boat  drifted back. ',
#  'that--"  but again the boat tore ahead  as',
#  'not a chip of the boat was harmed, nor a',
#  'desisted from  rowing; the boat drifted a little towards',
#  'in that manner the mutinous boat  rapidly shot away',
#  'the  bow-oar in his boat (the second one from',
#  'hands now jumped into a boat alongside,  and pushed',
#  'he  slewed round his boat and made after the',
#  "he had had,  derick's boat still led the chase,",
#  "while, in consequence, derick's  boat was nigh to capsizing,",
#  "showers of gore, capsizing flask's boat  and marring the",
#  'so that ere long every boat was a buoy; the',
#  'view is to make the boat slide bravely.  queequeg',
#  ' but to haul the boat up to his flank',
#  'no ribs of man or boat can withstand it. ',
#  'about us; our beset  boat was like a ship',
#  'comes into requisition.  our boat was furnished with ',
#  'discovered from our low  boat that seemed playing up',
#  'then visiting our  becalmed boat from the margin of',
#  'away!"    the boat was now all but',
#  'their  lines, but their boat itself.  ultimately the',
#  "administering  three or four boat loads of brandreth's pills,",
#  'upon the second lowering, the boat paddled upon the whale;',
#  "gave chase; and  stubb's boat was now so far",
#  "ship's side from a  boat on the open sea;",
#  'great swells now lift the boat high up  towards',
#  'five whales, and  my boat fastened to one of',
#  'lima tower,  cutting my boat in two, leaving each',
#  'a thwart of  his boat that his ivory leg',
#  'shaping their various weapons and boat furniture.  often he',
#  'reached till morning; and the boat that had  killed',
#  "side all night; and that boat was ahab's.  ",
#  ' aye," lighting from the boat to the deck, ',
#  "the cranes, the windward quarter boat  (ahab's) did not",
#  'day noon? now mark his boat  there; where is',
#  'been necessitated to leave that boat to its fate ',
#  " one in that missing boat wore off that captain's",
#  'glittering mouth yawned beneath the boat like  an open-doored',
#  'this timely spinning round the boat upon its axis, ',
#  'that preluding moment, ere the boat was yet snapped, ahab,',
#  'final effort to push the boat out of the bite.',
#  'sideways as it slipped, the boat had shaken off his',
#  'the sight of the splintered boat seemed to madden ',
#  "  dragged into stubb's boat with blood-shot, blinded eyes,",
#  'the case that when a boat is stove, its crew,',
#  'the added power of the boat did not equal the',
#  'two parts of the wrecked boat having been  previously',
#  "the three crews.  ahab's boat was central; and cheering",
#  "thousand concreted perils,--ahab's yet unstricken boat seemed  drawn up",
#  ' in an instant the boat was pulling round close',
#  'high-lifted then; and  the boat leaped on.  ',
#  'this way accompanied the  boat with their bites. ',
#  'seemed to follow that one boat without  molesting the',
#  'offers to jump from this boat i stand in, that',
#  'the rising wind, the lonely boat was swiftly impelled ',
#  'as it seemed, from the boat so  rapidly nearing',
#  'it, so suddenly canted the boat over, that had it',
#  'their seats, and tow the boat up to the mark;',
#  'the oarsmen violently forced their boat through the  sledge-hammering',
#  'almost, the temporarily  disabled boat lay nearly level with',
#  'circles seized the lone  boat itself, and all its']

# %%
# everything seems to work:))

len(concordance_moby)
# Out:
# 128

# %% [markdown]
# ## Challenge 2: compare lengths of books
#
# We can use the command `len` to find how many items there are in a list. E.g., to find the number of words in the list called `bible`, above, we can write: `len(bible)`.
#
# Use the starter code below to find out which book in the books included in `nltk` has the most words.

# %%
# solution 1: print all the titles and numbers of words
# starter code:

books = nltk.corpus.gutenberg.fileids()

# I figured out how to use the loop yippieee :))
# Below I can see, that The Bible is the longest book

for title in books: 
    book = nltk.corpus.gutenberg.raw(title)
    book = book.lower()
    book = book.replace('\r', ' ')
    book = book.replace('\n', ' ')
    book = book.split(' ')
    len(book)
    print(title,'=', len(book))
    titles = []
    numwords = []
    titles.append(title)
    numwords.append(len(book))
# Out:
# austen-emma.txt = 164457
# austen-persuasion.txt = 86270
# austen-sense.txt = 123514
# bible-kjv.txt = 848001
# blake-poems.txt = 8886
# bryant-stories.txt = 54942
# burgess-busterbrown.txt = 17976
# carroll-alice.txt = 28387
# chesterton-ball.txt = 86481
# chesterton-brown.txt = 80382
# chesterton-thursday.txt = 59297
# edgeworth-parents.txt = 195982
# melville-moby_dick.txt = 243947
# milton-paradise.txt = 91832
# shakespeare-caesar.txt = 23339
# shakespeare-hamlet.txt = 33477
# shakespeare-macbeth.txt = 20164
# whitman-leaves.txt = 138730

# %%
# more advanced, for those with some Python experience, or those who want to google around..
# solution 2: make a list of titles and a list of wordcounts, zip them together, then sort them based on wordcount
# starter code:

books = nltk.corpus.gutenberg.fileids()

titles = []
numwords = []
    book = nltk.corpus.gutenberg.raw(title)

# %%
# I copy the loop and try to append the titles and numwords
# Always remember to make the lists outside of the loop, loops are a bit confusing

titles = []
numwords = []

for title in books: 
    book = nltk.corpus.gutenberg.raw(title)
    book = book.lower()
    book = book.replace('\r', ' ')
    book = book.replace('\n', ' ')
    book = book.split(' ')
    titles.append(title)
    numwords.append(len(book))

# %%
# I put the data into a dataframe, I like the way dataframes look

import pandas as pd

df = pd.DataFrame(
    {'Titles': titles,
     'Word Count': numwords,
    })
df
# Out:
#                      Titles  Word Count
# 0           austen-emma.txt      164457
# 1     austen-persuasion.txt       86270
# 2          austen-sense.txt      123514
# 3             bible-kjv.txt      848001
# 4           blake-poems.txt        8886
# 5        bryant-stories.txt       54942
# 6   burgess-busterbrown.txt       17976
# 7         carroll-alice.txt       28387
# 8       chesterton-ball.txt       86481
# 9      chesterton-brown.txt       80382
# 10  chesterton-thursday.txt       59297
# 11    edgeworth-parents.txt      195982
# 12   melville-moby_dick.txt      243947
# 13      milton-paradise.txt       91832
# 14   shakespeare-caesar.txt       23339
# 15   shakespeare-hamlet.txt       33477
# 16  shakespeare-macbeth.txt       20164
# 17       whitman-leaves.txt      138730

# %%
# This function sorts the data by word count, i found it via a simple google search
# "ascending = False" sorts the data in descending order

df.sort_values(by=['Word Count'], ascending = False)
# Out:
#                      Titles  Word Count
# 3             bible-kjv.txt      848001
# 12   melville-moby_dick.txt      243947
# 11    edgeworth-parents.txt      195982
# 0           austen-emma.txt      164457
# 17       whitman-leaves.txt      138730
# 2          austen-sense.txt      123514
# 13      milton-paradise.txt       91832
# 8       chesterton-ball.txt       86481
# 1     austen-persuasion.txt       86270
# 9      chesterton-brown.txt       80382
# 10  chesterton-thursday.txt       59297
# 5        bryant-stories.txt       54942
# 15   shakespeare-hamlet.txt       33477
# 7         carroll-alice.txt       28387
# 14   shakespeare-caesar.txt       23339
# 16  shakespeare-macbeth.txt       20164
# 6   burgess-busterbrown.txt       17976
# 4           blake-poems.txt        8886

# %% [markdown]
# ## Challenge 3: what are the most frequent words?
#
# `nltk` has a built-in function called `FreqDist` which counts up how many times each word in a text occurs. So, if you have a list called `words` which contains all the words in a book, you can find the frequencies of all of them by writing `freq = nltk.FreqDist(words)`. You can then get the e.g. ten most common words by writing `freq.most_common(10)`. What are the ten most common words in Jane Austen's "Emma"? What about Herman Melville's "Moby Dick"?

# %%
# I used the code from the very beginning of challenge 1
# I'm not sure if there's a more efficient method, but it seems to work just fine

emma = nltk.corpus.gutenberg.raw('austen-emma.txt')

emma = emma.lower()

emma = emma.replace('\n', '/r')

emma = emma.split(' ')

# %%
# Here i found the 10 most common words in "Emma"
# I'm not sure how to remove '' (number 3 in the list)

freq = nltk.FreqDist(emma)

freq.most_common(10)
# Out:
# [('the', 4522),
#  ('to', 4497),
#  ('', 3704),
#  ('of', 3651),
#  ('and', 3449),
#  ('a', 2760),
#  ('i', 2151),
#  ('was', 2066),
#  ('not', 1819),
#  ('in', 1815)]

# %%
# Same deal, this time with Moby Dick and 20 words

moby = nltk.corpus.gutenberg.raw('melville-moby_dick.txt')

moby = moby.lower()

moby = moby.replace('\n', '/r')

moby = moby.split(' ')

freq = nltk.FreqDist(moby)

freq.most_common(20)
# Out:
# [('the', 11791),
#  ('', 5719),
#  ('of', 5709),
#  ('and', 5232),
#  ('to', 3978),
#  ('a', 3949),
#  ('in', 3533),
#  ('that', 2327),
#  ('his', 2061),
#  ('it', 1503),
#  ('i', 1487),
#  ('as', 1485),
#  ('with', 1454),
#  ('he', 1448),
#  ('was', 1390),
#  ('is', 1380),
#  ('for', 1315),
#  ('but', 1315),
#  ('all', 1141),
#  ('at', 1109)]

# %% [markdown]
# ## Challenge 4: Remove stopwords
#
# Often, the most frequent words are not the most interesting ones. Words like "a" and "the" are so common in English, that they don't really tell us much about the text. That is why we often remove "stopwords", that is, a list of the most common words in English, before e.g. counting frequencies. There are several of these lists available, in [English]((https://gist.github.com/sebleier/554280)) as well as other languages, such as [Danish](https://gist.github.com/berteltorp/0cf8a0c7afea7f25ed754f24cfc2467b). Below is some starter code to remove stopwords. Use these snippets to see what the most common words in Emma and Moby Dick are after removing these most common words.
#
# Hint: In Moby Dick, you will also have to remove the string `\r`, in addition to removing `\n`.

# %%
# list of stopwords

stopwords = ["", "i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
# I will now try to find the 10 most common words in Hamlet, excluding stop words.
# Yay it seems to work!

hamlet = nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt')
hamlet = hamlet.lower()
hamlet = hamlet.replace('\n', '/r')
hamlet = hamlet.split(' ')
hamlet = [word for word in hamlet if word not in stopwords]
freq.most_common(10)
freq = nltk.FreqDist(hamlet)

freq
# Out:
# FreqDist({'ham.': 337, 'haue': 155, 'shall': 99, 'hor.': 95, 'king.': 89, 'thou': 85, 'thy': 85, 'good': 83, 'let': 72, 'like': 62, ...})
